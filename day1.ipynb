# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales = pd.read_csv("superstore.csv", encoding="latin-1")
customers = pd.read_csv("customers.csv", encoding="latin-1")
churn = pd.read_csv("churn.csv", encoding="latin-1")
marketing = pd.read_csv("marketing.csv", encoding="latin-1")

# %%
sales.isnull().sum()
# Out:
# Order ID            0
# Order Date          0
# Ship Date           0
# Ship Mode           0
# Customer ID         0
# Customer Name       0
# Segment             0
# Country             0
# City                0
# State               0
# Postal Code         0
# Region              0
# Product ID          0
# Category            0
# Sub-Category        0
# Product Name        0
# Sales               0
# Quantity            0
# Discount            0
# Profit              0
# Unnamed: 20      9993
# dtype: int64

# %%
sales.count
# Out:
# <bound method DataFrame.count of             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9993  CA-2017-119914    5/4/2017    5/9/2017    Second Class    CC-12220
#
# ...

# %%
sales.drop(range(2240,9994),inplace=True)

# %%
sales.isnull().sum()
# Out:
# Order ID            0
# Order Date          0
# Ship Date           0
# Ship Mode           0
# Customer ID         0
# Customer Name       0
# Segment             0
# Country             0
# City                0
# State               0
# Postal Code         0
# Region              0
# Product ID          0
# Category            0
# Sub-Category        0
# Product Name        0
# Sales               0
# Quantity            0
# Discount            0
# Profit              0
# Unnamed: 20      2239
# dtype: int64

# %%
sales.rename(columns={})
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 2235  CA-2015-145849   9/15/2015   9/17/2015    Second Class    CT-11995
# 2236  CA-2015-145849   9/15/2015   9/17/2015    Second Class    CT-11995
# 2237  CA-2016-122322   7/15/2016   7/21/2016  Standard Class    RH-19510
# 2238  CA-2017-166849   4/20/2017   4/26/2017  Standard Class    SJ-20125
# 2239  CA-2016-146633  11/15/2016  11/17/2016    Second Class    TG-21310
#
#         Customer Name      Segment        Country             City  \
# ...

# %%
sales.drop(columns=['Unnamed: 20'],inplace=True)

# %%
sales.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
sns.histplot(sales['Sales'], bins=50, kde=True)
plt.title("Sales Distribution")
plt.show()

# %%
sns.barplot(x='Category', y='Sales', data=sales, estimator=sum)
plt.title("Total Sales by Category")
plt.xticks(rotation=45)
plt.show()

# %%
sns.scatterplot(x='Sales', y='Profit', data=sales)
plt.title("Sales vs Profit")
plt.show()

# %%
sns.barplot(x='Region', y='Sales', data=sales, estimator=sum)
plt.title("Sales by Region")
plt.show()
